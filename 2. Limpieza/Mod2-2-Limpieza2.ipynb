# %% [markdown]
# # Pair Programming Limpieza II

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import regex as re

# %% [markdown]
#  1. Columna de species: si exploramos esta columna en detalle nos podemos dar cuenta que tenemos muchos valores únicos y esto hace que sea muy difícil trabajar con esta columna. Lo que vamos a hacer es clasificar los tiburones en 5 especies diferentes, las más comunes, que incluyen el tiburón blanco (White), el tiburón tigre (Tiger ), el tiburón gris (Grey), el tiburón limón (Lemon) y el tiburón toro (Bull). El resto de las especies las incluiremos en un único grupo que podremos llamar "Unspecified". Ahora nos podemos sentir un poco abrumadas y no saber como enfrentarnos a este reto, pero don't worry, os dejamos por aquí unas 💡 pistas 💡 para que os ayuden a entender cómo hacerlo.

# %% [markdown]
# * Los valores de las columnas son strings por lo que podremos usar regex para buscar palabras clave en cada celda y asignarlo a una de las categorías que hemos definido previamente.

# %%
df = pd.read_csv("datos/1.ataques_limpio.csv", index_col=0)

# %%
df.head(2)
# Out:
#     case_number    year country age     species_  mes fatal sexo
# 0    2018.06.25  2018.0     USA  57  White shark  Jun     n    F
# 1  2018.06.03.a  2018.0  BRAZIL  18  Tiger shark  Jun     y    M

# %%
df["species_"].unique()
# Out:
# array(['White shark', 'Tiger shark', "Bull shark, 6'", 'Grey reef shark',
#        'Invalid incident', '3 m shark', 'White shark, 2.5 m',
#        "Tiger shark, 12'", 'Wobbegong shark', '3.5 m shark',
#        '1.8 m shark', 'Juvenile white shark,  2.7 to 3.2 m',
#        'Bull shark, 2 m', 'small shark', 'White shark, 4.6 m',
#        '2 m shark', 'Wobbegong shark, 1 m', 'White shark, 4.5 m',
#        'Tiger shark, 8 to 10 feet', "8' shark", 'Questionable',
#        "5' to 6' shark", 'White shark, 3 to 3.5m ', 'White shark, 3 m',
#        'Shark involvement questionable', "White shark, 5' to 7'",
#        'Possibly a juvenile blacktip shark', "4' shark", 'A small shark',
#        "White shark, 11' to 13'", "White shark, 8' to 10'",
#        "Bull shark, 4' to 5'", 'White shark, 4 m',
#        'Shark involvement highly doubtful', "Bull shark, 5' to 7'",
#        'Bull shark, 4 m', 'Bull shark, 1 m',
#        'Shark involvement not confirmed', 'Wobbegong shark, 2m',
# ...

# %%
def cambiar_especie(col):

    patron_blanco= r".*[Ww](hite|HITE).*"
    patron_tigre = r".*[Tt](iger|IGER).*"
    patron_gris = r".*[Gg](rey|REY).*"
    patron_lemon = r".*[Ll](emon|EMON).*"
    patron_bull = r".*[Bb](ull|ULL).*"

    try: 
        if re.findall(patron_blanco,col):
            return "White"
        elif re.findall(patron_tigre,i):
            return "Tiger"
        elif re.findall(patron_gris,i):
            return "Grey"
        elif re.findall(patron_lemon,i):
            return "Lemon"
        elif re.findall(patron_bull,i):
            return "Bull"
        else:
            return "Unspecified"
    except:
        return np.nan

# %%
df["especie_cat"] = (df["species_"].apply(cambiar_especie))

# %%
df.sample(10)
# Out:
#        case_number    year       country  age  \
# 281   2012.03.14.a  2012.0           USA   17
# 1505    1791.00.00  1791.0     AUSTRALIA  NaN
# 796     1999.07.26  1999.0           USA   43
# 1103    1981.05.10  1981.0  SOUTH AFRICA   19
# 669     2003.01.17  2003.0  SOUTH AFRICA   14
# 930     1993.01.05  1993.0     AUSTRALIA   21
# 92      2015.10.19  2015.0           USA   21
# 798     1999.07.15  1999.0  SOUTH AFRICA   14
# 1330    1960.12.24  1960.0  SOUTH AFRICA   25
# 951     1992.02.09  1992.0     AUSTRALIA   19
#
#                                                species_  mes fatal sexo  \
# 281                                      4' to 5' shark  Mar     n    M
# 1505                                                NaN  NaN     y    F
# 796                              Bull shark, 2.1 m [7']  Jul     n    M
# 1103                  Raggedtooth shark, 2.5 m [8.25']   May     n    M
# 669   Shark involvement prior to death was not confi...  Jan   NaN    M
# ...

# %% [markdown]
# 2. Columna de age: es una columna de tipo string pero debería ser de tipo integer. Además, en esta columna nos vamos a encontrar con algunos errores tipográficos, estos incluyen:

# %%
df["age"].unique()
# Out:
# array(['57', '18', '15', '32', '21', '30', '60', '33', '19', '25', '10',
#        '69', '55', '35', '20', '54', '22', '31', '40', '37', '11', '13',
#        '34', '50', '46', '48', '17', '28', '65', '73', '58', '36', '60s',
#        '51', '61', '59', '42', '6', '27', '23', '29', '39', '24', '12',
#        '26', '71', '43', '9', '44', '14', '62', '52', '38', '68', '16',
#        '47', '63', '70', '41', '40s', '53', '20s', '7', '66', '45', '74',
#        '64', '8', '56', '49', '18 or 20', 'Teen', '30s', '77', '8 or 10',
#        '84', '\xa0 ', ' ', '30 or 36', '6½', '5', ' 30', ' 28', "60's",
#        '67', '>50', '? & 19', '21, 34,24 & 35', '30 & 32', '13 or 18',
#        '7 or 8', '9 or 10', nan, 'young', '13 or 14'], dtype=object)

# %%
def edad_en_int (col):

    patron= "regex"

    try:
        col.astype(str, inplace= True)
        if re.findall("/&|½|or|>",col):
            return col.replace("patron" , " ")

    except:
        return col

# %%
df["edad_int"] = (df["age"].apply(edad_en_int))

# %%
df["edad_int"].unique()
# Out:
# array(['57', '18', '15', '32', '21', '30', '60', '33', '19', '25', '10',
#        '69', '55', '35', '20', '54', '22', '31', '40', '37', '11', '13',
#        '34', '50', '46', '48', '17', '28', '65', '73', '58', '36', '60s',
#        '51', '61', '59', '42', '6', '27', '23', '29', '39', '24', '12',
#        '26', '71', '43', '9', '44', '14', '62', '52', '38', '68', '16',
#        '47', '63', '70', '41', '40s', '53', '20s', '7', '66', '45', '74',
#        '64', '8', '56', '49', '18 or 20', 'Teen', '30s', '77', '8 or 10',
#        '84', '\xa0 ', ' ', '30 or 36', '6½', '5', ' 30', ' 28', "60's",
#        '67', '>50', '? & 19', '21, 34,24 & 35', '30 & 32', '13 or 18',
#        '7 or 8', '9 or 10', nan, 'young', '13 or 14'], dtype=object)
