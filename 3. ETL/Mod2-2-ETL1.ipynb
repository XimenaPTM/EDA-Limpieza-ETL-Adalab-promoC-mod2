# %% [markdown]
# # Pair Programming ETL I

# %% [markdown]
# Vamos a nutrir los datos de los ataques de los tiburones con información climática de los paises que tenemos. Para eso vamos a usar la API del clima que hemos aprendido en la clase invertida:

# %% [markdown]
# Requisitos de este ejercicio de pair programming:
# * Deberéis meter toda la información climática en un único dataframe.
# * Deberéis hacer la llamada a la API de una sola vez. Es decir, tendréis que iterar por la lista de países y sacar la información del clima para cada uno de ellos.
# * Al meter toda la información en un único dataframe tendremos que crear una columna que corresponda con el nombre del país.
# * Guardar el dataframe obtenido para usarlo en la siguiente sesión de pair programming.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 

import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Vamos a crear un diccionario:

# %%
dic_paises = {"USA":[-100.445882,39.7837304,], 
            "Australia":[134.755,-24.7761086],
            "South_Africa":[24.991639,-28.8166236],
            "New Zealand":[172.8344077,-41.5000831],
            "Papua New Guinea":[144.2489081,-5.6816069]}
dic_paises
# Out:
# {'USA': [-100.445882, 39.7837304],
#  'Australia': [134.755, -24.7761086],
#  'South_Africa': [24.991639, -28.8166236],
#  'New Zealand': [172.8344077, -41.5000831],
#  'Papua New Guinea': [144.2489081, -5.6816069]}

# %%
df_final = pd.DataFrame()

# %%
for k,v in dic_paises.items():
    lon = (v[0])
    lat = (v[1])
    producto = "meteo"

    url = f'http://www.7timer.info/bin/api.pl?lon=-{lon}&lat={lat}&product={producto}&output=json'
    
    response = requests.get(url=url)
    
    codigo_estado = response.status_code
    
    razon_estado = response.reason
    
    if codigo_estado == 200:
        print('La peticion se ha realizado correctamente, se ha devuelto el código de estado:',codigo_estado,' y como razón del código de estado: ',razon_estado)
    elif codigo_estado == 402:
        print('No se ha podido autorizar usario, se ha devuelto el código de estado:', codigo_estado,' y como razón del código de estado: ',razon_estado)
    elif codigo_estado == 404:
        print('Algo ha salido mal, el recurso no se ha encontrado,se ha devuelto el código de estado:', codigo_estado,' y como razón del código de estado: ',razon_estado)
    else:
        print('Algo inesperado ha ocurrido, se ha devuelto el código de estado:', codigo_estado,' y como razón del código de estado: ',razon_estado)
    
    response.json()
#Hay que convertir los datos obtenidos en un df
    df = pd.DataFrame.from_dict(pd.json_normalize(response.json()['dataseries']))
    # Creamos una columna llamada país donde se vaya registrando cada país
    df["pais"] = k

# Concatenamos los df que hemos obtenido con cada país
df_final = pd.concat([df_final,df],axis=0, ignore_index= True)
# Out:
# La peticion se ha realizado correctamente, se ha devuelto el código de estado: 200  y como razón del código de estado:  OK
# {'product': 'meteo',
#  'init': '2023011112',
#  'dataseries': [{'timepoint': 3,
#    'cloudcover': 7,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 5},
#     {'layer': '900mb', 'rh': 7},
#     {'layer': '850mb', 'rh': 8},
#     {'layer': '800mb', 'rh': 13},
#     {'layer': '750mb', 'rh': 11},
#     {'layer': '700mb', 'rh': 7},
#     {'layer': '650mb', 'rh': 3},
#     {'layer': '600mb', 'rh': 1},
#     {'layer': '550mb', 'rh': 3},
#     {'layer': '500mb', 'rh': 10},
#     {'layer': '450mb', 'rh': 11},
#     {'layer': '400mb', 'rh': 11},
#     {'layer': '350mb', 'rh': 13},
#     {'layer': '300mb', 'rh': 15},
#     {'layer': '250mb', 'rh': 15},
#     {'layer': '200mb', 'rh': 14}],
#    'wind_profile': [{'layer': '950mb', 'direction': 150, 'speed': 2},
#     {'layer': '900mb', 'direction': 240, 'speed': 2},
#     {'layer': '850mb', 'direction': 260, 'speed': 3},
#     {'layer': '800mb', 'direction': 275, 'speed': 3},
#     {'layer': '750mb', 'direction': 280, 'speed': 4},
#     {'layer': '700mb', 'direction': 265, 'speed': 5},
#     {'layer': '650mb', 'direction': 270, 'speed': 5},
#     {'layer': '600mb', 'direction': 265, 'speed': 6},
#     {'layer': '550mb', 'direction': 255, 'speed': 6},
#     {'layer': '500mb', 'direction': 250, 'speed': 6},
#     {'layer': '450mb', 'direction': 245, 'speed': 6},
#     {'layer': '400mb', 'direction': 250, 'speed': 6},
#     {'layer': '350mb', 'direction': 250, 'speed': 6},
#     {'layer': '300mb', 'direction': 250, 'speed': 7},
#     {'layer': '250mb', 'direction': 245, 'speed': 7},
#     {'layer': '200mb', 'direction': 250, 'speed': 7}],
#    'temp2m': 16,
#    'lifted_index': 6,
#    'rh2m': 4,
#    'msl_pressure': 1024,
#    'wind10m': {'direction': '110', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 6,
#    'cloudcover': 8,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 6},
#     {'layer': '900mb', 'rh': 7},
#     {'layer': '850mb', 'rh': 6},
#     {'layer': '800mb', 'rh': 8},
#     {'layer': '750mb', 'rh': 11},
#     {'layer': '700mb', 'rh': 6},
#     {'layer': '650mb', 'rh': 3},
#     {'layer': '600mb', 'rh': 8},
#     {'layer': '550mb', 'rh': 15},
#     {'layer': '500mb', 'rh': 16},
#     {'layer': '450mb', 'rh': 16},
#     {'layer': '400mb', 'rh': 16},
#     {'layer': '350mb', 'rh': 16},
#     {'layer': '300mb', 'rh': 12},
#     {'layer': '250mb', 'rh': 14},
#     {'layer': '200mb', 'rh': 6}],
#    'wind_profile': [{'layer': '950mb', 'direction': 265, 'speed': 2},
#     {'layer': '900mb', 'direction': 330, 'speed': 3},
#     {'layer': '850mb', 'direction': 340, 'speed': 4},
#     {'layer': '800mb', 'direction': 340, 'speed': 3},
#     {'layer': '750mb', 'direction': 325, 'speed': 3},
#     {'layer': '700mb', 'direction': 305, 'speed': 3},
#     {'layer': '650mb', 'direction': 295, 'speed': 4},
#     {'layer': '600mb', 'direction': 275, 'speed': 6},
#     {'layer': '550mb', 'direction': 265, 'speed': 6},
#     {'layer': '500mb', 'direction': 260, 'speed': 6},
#     {'layer': '450mb', 'direction': 250, 'speed': 7},
#     {'layer': '400mb', 'direction': 255, 'speed': 7},
#     {'layer': '350mb', 'direction': 255, 'speed': 7},
#     {'layer': '300mb', 'direction': 245, 'speed': 7},
#     {'layer': '250mb', 'direction': 250, 'speed': 7},
#     {'layer': '200mb', 'direction': 255, 'speed': 7}],
#    'temp2m': 15,
#    'lifted_index': 6,
#    'rh2m': 6,
#    'msl_pressure': 1025,
#    'wind10m': {'direction': '220', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 9,
#    'cloudcover': 5,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 6},
#     {'layer': '900mb', 'rh': 7},
#     {'layer': '850mb', 'rh': 7},
#     {'layer': '800mb', 'rh': 3},
#     {'layer': '750mb', 'rh': 5},
#     {'layer': '700mb', 'rh': 8},
#     {'layer': '650mb', 'rh': 4},
#     {'layer': '600mb', 'rh': 1},
#     {'layer': '550mb', 'rh': -3},
#     {'layer': '500mb', 'rh': -2},
#     {'layer': '450mb', 'rh': -3},
#     {'layer': '400mb', 'rh': 0},
#     {'layer': '350mb', 'rh': -2},
#     {'layer': '300mb', 'rh': -1},
#     {'layer': '250mb', 'rh': 1},
#     {'layer': '200mb', 'rh': 1}],
#    'wind_profile': [{'layer': '950mb', 'direction': 275, 'speed': 2},
#     {'layer': '900mb', 'direction': 255, 'speed': 2},
#     {'layer': '850mb', 'direction': 355, 'speed': 3},
#     {'layer': '800mb', 'direction': 5, 'speed': 4},
#     {'layer': '750mb', 'direction': 15, 'speed': 3},
#     {'layer': '700mb', 'direction': 295, 'speed': 3},
#     {'layer': '650mb', 'direction': 295, 'speed': 4},
#     {'layer': '600mb', 'direction': 285, 'speed': 5},
#     {'layer': '550mb', 'direction': 280, 'speed': 5},
#     {'layer': '500mb', 'direction': 275, 'speed': 5},
#     {'layer': '450mb', 'direction': 275, 'speed': 5},
#     {'layer': '400mb', 'direction': 265, 'speed': 6},
#     {'layer': '350mb', 'direction': 275, 'speed': 6},
#     {'layer': '300mb', 'direction': 265, 'speed': 6},
#     {'layer': '250mb', 'direction': 260, 'speed': 7},
#     {'layer': '200mb', 'direction': 270, 'speed': 6}],
#    'temp2m': 14,
#    'lifted_index': 6,
#    'rh2m': 7,
#    'msl_pressure': 1028,
#    'wind10m': {'direction': '205', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 12,
#    'cloudcover': 3,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 8},
#     {'layer': '900mb', 'rh': 8},
#     {'layer': '850mb', 'rh': 5},
#     {'layer': '800mb', 'rh': -1},
#     {'layer': '750mb', 'rh': 2},
#     {'layer': '700mb', 'rh': 2},
#     {'layer': '650mb', 'rh': -3},
#     {'layer': '600mb', 'rh': -3},
#     {'layer': '550mb', 'rh': -2},
#     {'layer': '500mb', 'rh': -1},
#     {'layer': '450mb', 'rh': 0},
#     {'layer': '400mb', 'rh': 0},
#     {'layer': '350mb', 'rh': -1},
#     {'layer': '300mb', 'rh': 0},
#     {'layer': '250mb', 'rh': 0},
#     {'layer': '200mb', 'rh': -1}],
#    'wind_profile': [{'layer': '950mb', 'direction': 80, 'speed': 2},
#     {'layer': '900mb', 'direction': 260, 'speed': 2},
#     {'layer': '850mb', 'direction': 310, 'speed': 2},
#     {'layer': '800mb', 'direction': 330, 'speed': 3},
#     {'layer': '750mb', 'direction': 315, 'speed': 2},
#     {'layer': '700mb', 'direction': 330, 'speed': 3},
#     {'layer': '650mb', 'direction': 355, 'speed': 3},
#     {'layer': '600mb', 'direction': 40, 'speed': 5},
#     {'layer': '550mb', 'direction': 30, 'speed': 6},
#     {'layer': '500mb', 'direction': 35, 'speed': 6},
#     {'layer': '450mb', 'direction': 35, 'speed': 5},
#     {'layer': '400mb', 'direction': 15, 'speed': 5},
#     {'layer': '350mb', 'direction': 25, 'speed': 6},
#     {'layer': '300mb', 'direction': 25, 'speed': 6},
#     {'layer': '250mb', 'direction': 20, 'speed': 5},
#     {'layer': '200mb', 'direction': 280, 'speed': 6}],
#    'temp2m': 13,
#    'lifted_index': 10,
#    'rh2m': 7,
#    'msl_pressure': 1028,
#    'wind10m': {'direction': '280', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 15,
#    'cloudcover': 1,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 6},
#     {'layer': '900mb', 'rh': 3},
#     {'layer': '850mb', 'rh': 3},
#     {'layer': '800mb', 'rh': -2},
#     {'layer': '750mb', 'rh': -3},
#     {'layer': '700mb', 'rh': -4},
#     {'layer': '650mb', 'rh': -3},
#     {'layer': '600mb', 'rh': -1},
#     {'layer': '550mb', 'rh': -1},
#     {'layer': '500mb', 'rh': -1},
#     {'layer': '450mb', 'rh': 0},
#     {'layer': '400mb', 'rh': 0},
#     {'layer': '350mb', 'rh': 0},
#     {'layer': '300mb', 'rh': 0},
#     {'layer': '250mb', 'rh': 3},
#     {'layer': '200mb', 'rh': 7}],
#    'wind_profile': [{'layer': '950mb', 'direction': 90, 'speed': 2},
#     {'layer': '900mb', 'direction': 135, 'speed': 2},
#     {'layer': '850mb', 'direction': 225, 'speed': 2},
#     {'layer': '800mb', 'direction': 315, 'speed': 2},
#     {'layer': '750mb', 'direction': 325, 'speed': 3},
#     {'layer': '700mb', 'direction': 345, 'speed': 4},
#     {'layer': '650mb', 'direction': 30, 'speed': 3},
#     {'layer': '600mb', 'direction': 25, 'speed': 4},
#     {'layer': '550mb', 'direction': 25, 'speed': 5},
#     {'layer': '500mb', 'direction': 30, 'speed': 4},
#     {'layer': '450mb', 'direction': 30, 'speed': 5},
#     {'layer': '400mb', 'direction': 25, 'speed': 5},
#     {'layer': '350mb', 'direction': 30, 'speed': 6},
#     {'layer': '300mb', 'direction': 20, 'speed': 6},
#     {'layer': '250mb', 'direction': 5, 'speed': 7},
#     {'layer': '200mb', 'direction': 345, 'speed': 4}],
#    'temp2m': 13,
#    'lifted_index': 15,
#    'rh2m': 4,
#    'msl_pressure': 1028,
#    'wind10m': {'direction': '205', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 18,
#    'cloudcover': 1,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 8},
#     {'layer': '900mb', 'rh': 5},
#     {'layer': '850mb', 'rh': 5},
#     {'layer': '800mb', 'rh': -1},
#     {'layer': '750mb', 'rh': -3},
#     {'layer': '700mb', 'rh': -2},
#     {'layer': '650mb', 'rh': -1},
#     {'layer': '600mb', 'rh': 0},
#     {'layer': '550mb', 'rh': -1},
#     {'layer': '500mb', 'rh': -1},
#     {'layer': '450mb', 'rh': -1},
#     {'layer': '400mb', 'rh': -1},
#     {'layer': '350mb', 'rh': -1},
#     {'layer': '300mb', 'rh': 7},
#     {'layer': '250mb', 'rh': 15},
#     {'layer': '200mb', 'rh': 6}],
#    'wind_profile': [{'layer': '950mb', 'direction': 150, 'speed': 2},
#     {'layer': '900mb', 'direction': 205, 'speed': 2},
#     {'layer': '850mb', 'direction': 250, 'speed': 2},
#     {'layer': '800mb', 'direction': 330, 'speed': 3},
#     {'layer': '750mb', 'direction': 330, 'speed': 4},
#     {'layer': '700mb', 'direction': 350, 'speed': 3},
#     {'layer': '650mb', 'direction': 15, 'speed': 3},
#     {'layer': '600mb', 'direction': 10, 'speed': 3},
#     {'layer': '550mb', 'direction': 20, 'speed': 3},
#     {'layer': '500mb', 'direction': 35, 'speed': 3},
#     {'layer': '450mb', 'direction': 25, 'speed': 4},
#     {'layer': '400mb', 'direction': 15, 'speed': 5},
#     {'layer': '350mb', 'direction': 20, 'speed': 5},
#     {'layer': '300mb', 'direction': 5, 'speed': 6},
#     {'layer': '250mb', 'direction': 0, 'speed': 7},
#     {'layer': '200mb', 'direction': 320, 'speed': 3}],
#    'temp2m': 13,
#    'lifted_index': 15,
#    'rh2m': 3,
#    'msl_pressure': 1028,
#    'wind10m': {'direction': '200', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 21,
#    'cloudcover': 6,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 5},
#     {'layer': '900mb', 'rh': 5},
#     {'layer': '850mb', 'rh': 1},
#     {'layer': '800mb', 'rh': -1},
#     {'layer': '750mb', 'rh': 0},
#     {'layer': '700mb', 'rh': 1},
#     {'layer': '650mb', 'rh': 1},
#     {'layer': '600mb', 'rh': 1},
#     {'layer': '550mb', 'rh': -1},
#     {'layer': '500mb', 'rh': 0},
#     {'layer': '450mb', 'rh': -1},
#     {'layer': '400mb', 'rh': -1},
#     {'layer': '350mb', 'rh': 6},
#     {'layer': '300mb', 'rh': 8},
#     {'layer': '250mb', 'rh': 5},
#     {'layer': '200mb', 'rh': 3}],
#    'wind_profile': [{'layer': '950mb', 'direction': 220, 'speed': 2},
#     {'layer': '900mb', 'direction': 240, 'speed': 2},
#     {'layer': '850mb', 'direction': 330, 'speed': 2},
#     {'layer': '800mb', 'direction': 335, 'speed': 3},
#     {'layer': '750mb', 'direction': 345, 'speed': 3},
#     {'layer': '700mb', 'direction': 10, 'speed': 3},
#     {'layer': '650mb', 'direction': 0, 'speed': 3},
#     {'layer': '600mb', 'direction': 340, 'speed': 3},
#     {'layer': '550mb', 'direction': 315, 'speed': 2},
#     {'layer': '500mb', 'direction': 325, 'speed': 2},
#     {'layer': '450mb', 'direction': 345, 'speed': 3},
#     {'layer': '400mb', 'direction': 345, 'speed': 4},
#     {'layer': '350mb', 'direction': 340, 'speed': 5},
#     {'layer': '300mb', 'direction': 10, 'speed': 6},
#     {'layer': '250mb', 'direction': 5, 'speed': 7},
#     {'layer': '200mb', 'direction': 15, 'speed': 5}],
#    'temp2m': 12,
#    'lifted_index': 15,
#    'rh2m': 2,
#    'msl_pressure': 1029,
#    'wind10m': {'direction': '240', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 24,
#    'cloudcover': 4,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 2},
#     {'layer': '900mb', 'rh': 0},
#     {'layer': '850mb', 'rh': 0},
#     {'layer': '800mb', 'rh': -1},
#     {'layer': '750mb', 'rh': 1},
#     {'layer': '700mb', 'rh': 1},
#     {'layer': '650mb', 'rh': 1},
#     {'layer': '600mb', 'rh': 1},
#     {'layer': '550mb', 'rh': -1},
#     {'layer': '500mb', 'rh': -2},
#     {'layer': '450mb', 'rh': -1},
#     {'layer': '400mb', 'rh': 11},
#     {'layer': '350mb', 'rh': 4},
#     {'layer': '300mb', 'rh': 2},
#     {'layer': '250mb', 'rh': 2},
#     {'layer': '200mb', 'rh': 3}],
#    'wind_profile': [{'layer': '950mb', 'direction': 215, 'speed': 2},
#     {'layer': '900mb', 'direction': 240, 'speed': 2},
#     {'layer': '850mb', 'direction': 340, 'speed': 2},
#     {'layer': '800mb', 'direction': 340, 'speed': 3},
#     {'layer': '750mb', 'direction': 340, 'speed': 3},
#     {'layer': '700mb', 'direction': 335, 'speed': 3},
#     {'layer': '650mb', 'direction': 320, 'speed': 3},
#     {'layer': '600mb', 'direction': 295, 'speed': 3},
#     {'layer': '550mb', 'direction': 290, 'speed': 3},
#     {'layer': '500mb', 'direction': 290, 'speed': 3},
#     {'layer': '450mb', 'direction': 300, 'speed': 3},
#     {'layer': '400mb', 'direction': 320, 'speed': 4},
#     {'layer': '350mb', 'direction': 350, 'speed': 5},
#     {'layer': '300mb', 'direction': 15, 'speed': 5},
#     {'layer': '250mb', 'direction': 10, 'speed': 7},
#     {'layer': '200mb', 'direction': 5, 'speed': 5}],
#    'temp2m': 12,
#    'lifted_index': 15,
#    'rh2m': 1,
#    'msl_pressure': 1028,
#    'wind10m': {'direction': '195', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 27,
#    'cloudcover': 1,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 1},
#     {'layer': '900mb', 'rh': -1},
#     {'layer': '850mb', 'rh': -1},
#     {'layer': '800mb', 'rh': 0},
#     {'layer': '750mb', 'rh': 1},
#     {'layer': '700mb', 'rh': 1},
#     {'layer': '650mb', 'rh': 2},
#     {'layer': '600mb', 'rh': 2},
#     {'layer': '550mb', 'rh': 0},
#     {'layer': '500mb', 'rh': -1},
#     {'layer': '450mb', 'rh': 6},
#     {'layer': '400mb', 'rh': 7},
#     {'layer': '350mb', 'rh': 2},
#     {'layer': '300mb', 'rh': 5},
#     {'layer': '250mb', 'rh': 7},
#     {'layer': '200mb', 'rh': 4}],
#    'wind_profile': [{'layer': '950mb', 'direction': 235, 'speed': 2},
#     {'layer': '900mb', 'direction': 265, 'speed': 2},
#     {'layer': '850mb', 'direction': 285, 'speed': 2},
#     {'layer': '800mb', 'direction': 315, 'speed': 3},
#     {'layer': '750mb', 'direction': 320, 'speed': 3},
#     {'layer': '700mb', 'direction': 310, 'speed': 3},
#     {'layer': '650mb', 'direction': 300, 'speed': 3},
#     {'layer': '600mb', 'direction': 295, 'speed': 4},
#     {'layer': '550mb', 'direction': 300, 'speed': 5},
#     {'layer': '500mb', 'direction': 290, 'speed': 4},
#     {'layer': '450mb', 'direction': 285, 'speed': 4},
#     {'layer': '400mb', 'direction': 310, 'speed': 3},
#     {'layer': '350mb', 'direction': 350, 'speed': 4},
#     {'layer': '300mb', 'direction': 5, 'speed': 5},
#     {'layer': '250mb', 'direction': 0, 'speed': 6},
#     {'layer': '200mb', 'direction': 355, 'speed': 7}],
#    'temp2m': 13,
#    'lifted_index': 15,
#    'rh2m': 4,
#    'msl_pressure': 1026,
#    'wind10m': {'direction': '200', 'speed': 3},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 30,
#    'cloudcover': 1,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 4},
#     {'layer': '900mb', 'rh': 1},
#     {'layer': '850mb', 'rh': 0},
#     {'layer': '800mb', 'rh': 0},
#     {'layer': '750mb', 'rh': 1},
#     {'layer': '700mb', 'rh': 2},
#     {'layer': '650mb', 'rh': 3},
#     {'layer': '600mb', 'rh': 2},
#     {'layer': '550mb', 'rh': 2},
#     {'layer': '500mb', 'rh': 5},
#     {'layer': '450mb', 'rh': 6},
#     {'layer': '400mb', 'rh': 5},
#     {'layer': '350mb', 'rh': 7},
#     {'layer': '300mb', 'rh': 15},
#     {'layer': '250mb', 'rh': 15},
#     {'layer': '200mb', 'rh': 7}],
#    'wind_profile': [{'layer': '950mb', 'direction': 220, 'speed': 2},
#     {'layer': '900mb', 'direction': 250, 'speed': 2},
#     {'layer': '850mb', 'direction': 285, 'speed': 3},
#     {'layer': '800mb', 'direction': 305, 'speed': 3},
#     {'layer': '750mb', 'direction': 310, 'speed': 3},
#     {'layer': '700mb', 'direction': 300, 'speed': 3},
#     {'layer': '650mb', 'direction': 300, 'speed': 3},
#     {'layer': '600mb', 'direction': 310, 'speed': 4},
#     {'layer': '550mb', 'direction': 310, 'speed': 5},
#     {'layer': '500mb', 'direction': 300, 'speed': 5},
#     {'layer': '450mb', 'direction': 295, 'speed': 4},
#     {'layer': '400mb', 'direction': 300, 'speed': 4},
#     {'layer': '350mb', 'direction': 310, 'speed': 4},
#     {'layer': '300mb', 'direction': 335, 'speed': 5},
#     {'layer': '250mb', 'direction': 340, 'speed': 6},
#     {'layer': '200mb', 'direction': 345, 'speed': 7}],
#    'temp2m': 13,
#    'lifted_index': 10,
#    'rh2m': 9,
#    'msl_pressure': 1026,
#    'wind10m': {'direction': '220', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 33,
#    'cloudcover': 8,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 5},
#     {'layer': '900mb', 'rh': 1},
#     {'layer': '850mb', 'rh': -1},
#     {'layer': '800mb', 'rh': -1},
#     {'layer': '750mb', 'rh': 0},
#     {'layer': '700mb', 'rh': 2},
#     {'layer': '650mb', 'rh': 3},
#     {'layer': '600mb', 'rh': 2},
#     {'layer': '550mb', 'rh': 3},
#     {'layer': '500mb', 'rh': 4},
#     {'layer': '450mb', 'rh': 4},
#     {'layer': '400mb', 'rh': 13},
#     {'layer': '350mb', 'rh': 15},
#     {'layer': '300mb', 'rh': 16},
#     {'layer': '250mb', 'rh': 16},
#     {'layer': '200mb', 'rh': 14}],
#    'wind_profile': [{'layer': '950mb', 'direction': 225, 'speed': 3},
#     {'layer': '900mb', 'direction': 250, 'speed': 3},
#     {'layer': '850mb', 'direction': 285, 'speed': 3},
#     {'layer': '800mb', 'direction': 310, 'speed': 3},
#     {'layer': '750mb', 'direction': 305, 'speed': 3},
#     {'layer': '700mb', 'direction': 295, 'speed': 3},
#     {'layer': '650mb', 'direction': 300, 'speed': 4},
#     {'layer': '600mb', 'direction': 310, 'speed': 4},
#     {'layer': '550mb', 'direction': 310, 'speed': 4},
#     {'layer': '500mb', 'direction': 310, 'speed': 4},
#     {'layer': '450mb', 'direction': 295, 'speed': 5},
#     {'layer': '400mb', 'direction': 295, 'speed': 5},
#     {'layer': '350mb', 'direction': 300, 'speed': 5},
#     {'layer': '300mb', 'direction': 305, 'speed': 5},
#     {'layer': '250mb', 'direction': 320, 'speed': 5},
#     {'layer': '200mb', 'direction': 325, 'speed': 7}],
#    'temp2m': 13,
#    'lifted_index': 15,
#    'rh2m': 8,
#    'msl_pressure': 1026,
#    'wind10m': {'direction': '260', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 36,
#    'cloudcover': 9,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 4},
#     {'layer': '900mb', 'rh': 1},
#     {'layer': '850mb', 'rh': 0},
#     {'layer': '800mb', 'rh': 0},
#     {'layer': '750mb', 'rh': 1},
#     {'layer': '700mb', 'rh': 1},
#     {'layer': '650mb', 'rh': -1},
#     {'layer': '600mb', 'rh': -1},
#     {'layer': '550mb', 'rh': 1},
#     {'layer': '500mb', 'rh': 7},
#     {'layer': '450mb', 'rh': 7},
#     {'layer': '400mb', 'rh': 16},
#     {'layer': '350mb', 'rh': 15},
#     {'layer': '300mb', 'rh': 16},
#     {'layer': '250mb', 'rh': 15},
#     {'layer': '200mb', 'rh': 13}],
#    'wind_profile': [{'layer': '950mb', 'direction': 230, 'speed': 2},
#     {'layer': '900mb', 'direction': 250, 'speed': 3},
#     {'layer': '850mb', 'direction': 270, 'speed': 3},
#     {'layer': '800mb', 'direction': 285, 'speed': 3},
#     {'layer': '750mb', 'direction': 290, 'speed': 3},
#     {'layer': '700mb', 'direction': 295, 'speed': 4},
#     {'layer': '650mb', 'direction': 300, 'speed': 4},
#     {'layer': '600mb', 'direction': 305, 'speed': 4},
#     {'layer': '550mb', 'direction': 310, 'speed': 4},
#     {'layer': '500mb', 'direction': 310, 'speed': 5},
#     {'layer': '450mb', 'direction': 315, 'speed': 5},
#     {'layer': '400mb', 'direction': 310, 'speed': 5},
#     {'layer': '350mb', 'direction': 300, 'speed': 5},
#     {'layer': '300mb', 'direction': 305, 'speed': 5},
#     {'layer': '250mb', 'direction': 315, 'speed': 6},
#     {'layer': '200mb', 'direction': 315, 'speed': 6}],
#    'temp2m': 13,
#    'lifted_index': 15,
#    'rh2m': 5,
#    'msl_pressure': 1025,
#    'wind10m': {'direction': '270', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 39,
#    'cloudcover': 9,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 2},
#     {'layer': '900mb', 'rh': 0},
#     {'layer': '850mb', 'rh': -1},
#     {'layer': '800mb', 'rh': -2},
#     {'layer': '750mb', 'rh': -3},
#     {'layer': '700mb', 'rh': -2},
#     {'layer': '650mb', 'rh': -1},
#     {'layer': '600mb', 'rh': 0},
#     {'layer': '550mb', 'rh': -1},
#     {'layer': '500mb', 'rh': -2},
#     {'layer': '450mb', 'rh': 6},
#     {'layer': '400mb', 'rh': 16},
#     {'layer': '350mb', 'rh': 14},
#     {'layer': '300mb', 'rh': 16},
#     {'layer': '250mb', 'rh': 16},
#     {'layer': '200mb', 'rh': 10}],
#    'wind_profile': [{'layer': '950mb', 'direction': 325, 'speed': 2},
#     {'layer': '900mb', 'direction': 290, 'speed': 2},
#     {'layer': '850mb', 'direction': 295, 'speed': 3},
#     {'layer': '800mb', 'direction': 300, 'speed': 3},
#     {'layer': '750mb', 'direction': 295, 'speed': 4},
#     {'layer': '700mb', 'direction': 290, 'speed': 4},
#     {'layer': '650mb', 'direction': 295, 'speed': 4},
#     {'layer': '600mb', 'direction': 305, 'speed': 5},
#     {'layer': '550mb', 'direction': 305, 'speed': 5},
#     {'layer': '500mb', 'direction': 305, 'speed': 5},
#     {'layer': '450mb', 'direction': 310, 'speed': 6},
#     {'layer': '400mb', 'direction': 305, 'speed': 5},
#     {'layer': '350mb', 'direction': 300, 'speed': 5},
#     {'layer': '300mb', 'direction': 300, 'speed': 5},
#     {'layer': '250mb', 'direction': 310, 'speed': 7},
#     {'layer': '200mb', 'direction': 305, 'speed': 7}],
#    'temp2m': 12,
#    'lifted_index': 15,
#    'rh2m': 3,
#    'msl_pressure': 1024,
#    'wind10m': {'direction': '280', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 42,
#    'cloudcover': 9,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 1},
#     {'layer': '900mb', 'rh': 0},
#     {'layer': '850mb', 'rh': -1},
#     {'layer': '800mb', 'rh': -2},
#     {'layer': '750mb', 'rh': -3},
#     {'layer': '700mb', 'rh': -3},
#     {'layer': '650mb', 'rh': -2},
#     {'layer': '600mb', 'rh': -2},
#     {'layer': '550mb', 'rh': -2},
#     {'layer': '500mb', 'rh': 0},
#     {'layer': '450mb', 'rh': 8},
#     {'layer': '400mb', 'rh': 14},
#     {'layer': '350mb', 'rh': 12},
#     {'layer': '300mb', 'rh': 8},
#     {'layer': '250mb', 'rh': 16},
#     {'layer': '200mb', 'rh': 10}],
#    'wind_profile': [{'layer': '950mb', 'direction': 35, 'speed': 3},
#     {'layer': '900mb', 'direction': 40, 'speed': 3},
#     {'layer': '850mb', 'direction': 15, 'speed': 3},
#     {'layer': '800mb', 'direction': 315, 'speed': 3},
#     {'layer': '750mb', 'direction': 295, 'speed': 4},
#     {'layer': '700mb', 'direction': 290, 'speed': 4},
#     {'layer': '650mb', 'direction': 285, 'speed': 5},
#     {'layer': '600mb', 'direction': 290, 'speed': 5},
#     {'layer': '550mb', 'direction': 295, 'speed': 5},
#     {'layer': '500mb', 'direction': 305, 'speed': 6},
#     {'layer': '450mb', 'direction': 310, 'speed': 6},
#     {'layer': '400mb', 'direction': 305, 'speed': 6},
#     {'layer': '350mb', 'direction': 310, 'speed': 5},
#     {'layer': '300mb', 'direction': 320, 'speed': 5},
#     {'layer': '250mb', 'direction': 335, 'speed': 7},
#     {'layer': '200mb', 'direction': 310, 'speed': 6}],
#    'temp2m': 12,
#    'lifted_index': 15,
#    'rh2m': 2,
#    'msl_pressure': 1024,
#    'wind10m': {'direction': '10', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 45,
#    'cloudcover': 8,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 2},
#     {'layer': '900mb', 'rh': 1},
#     {'layer': '850mb', 'rh': -1},
#     {'layer': '800mb', 'rh': -3},
#     {'layer': '750mb', 'rh': -3},
#     {'layer': '700mb', 'rh': -4},
#     {'layer': '650mb', 'rh': -2},
#     {'layer': '600mb', 'rh': 8},
#     {'layer': '550mb', 'rh': 14},
#     {'layer': '500mb', 'rh': 14},
#     {'layer': '450mb', 'rh': 4},
#     {'layer': '400mb', 'rh': 1},
#     {'layer': '350mb', 'rh': 2},
#     {'layer': '300mb', 'rh': 1},
#     {'layer': '250mb', 'rh': 7},
#     {'layer': '200mb', 'rh': 11}],
#    'wind_profile': [{'layer': '950mb', 'direction': 40, 'speed': 2},
#     {'layer': '900mb', 'direction': 320, 'speed': 2},
#     {'layer': '850mb', 'direction': 315, 'speed': 3},
#     {'layer': '800mb', 'direction': 330, 'speed': 3},
#     {'layer': '750mb', 'direction': 320, 'speed': 3},
#     {'layer': '700mb', 'direction': 295, 'speed': 4},
#     {'layer': '650mb', 'direction': 295, 'speed': 5},
#     {'layer': '600mb', 'direction': 305, 'speed': 5},
#     {'layer': '550mb', 'direction': 310, 'speed': 5},
#     {'layer': '500mb', 'direction': 310, 'speed': 5},
#     {'layer': '450mb', 'direction': 310, 'speed': 6},
#     {'layer': '400mb', 'direction': 305, 'speed': 5},
#     {'layer': '350mb', 'direction': 335, 'speed': 6},
#     {'layer': '300mb', 'direction': 320, 'speed': 6},
#     {'layer': '250mb', 'direction': 320, 'speed': 6},
#     {'layer': '200mb', 'direction': 305, 'speed': 7}],
#    'temp2m': 12,
#    'lifted_index': 15,
#    'rh2m': 0,
#    'msl_pressure': 1025,
#    'wind10m': {'direction': '330', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 48,
#    'cloudcover': 6,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 0},
#     {'layer': '900mb', 'rh': 2},
#     {'layer': '850mb', 'rh': 8},
#     {'layer': '800mb', 'rh': 9},
#     {'layer': '750mb', 'rh': 8},
#     {'layer': '700mb', 'rh': 10},
#     {'layer': '650mb', 'rh': 11},
#     {'layer': '600mb', 'rh': 3},
#     {'layer': '550mb', 'rh': 0},
#     {'layer': '500mb', 'rh': 1},
#     {'layer': '450mb', 'rh': -2},
#     {'layer': '400mb', 'rh': 2},
#     {'layer': '350mb', 'rh': 9},
#     {'layer': '300mb', 'rh': 1},
#     {'layer': '250mb', 'rh': 6},
#     {'layer': '200mb', 'rh': 14}],
#    'wind_profile': [{'layer': '950mb', 'direction': 270, 'speed': 2},
#     {'layer': '900mb', 'direction': 345, 'speed': 3},
#     {'layer': '850mb', 'direction': 345, 'speed': 3},
#     {'layer': '800mb', 'direction': 340, 'speed': 4},
#     {'layer': '750mb', 'direction': 320, 'speed': 3},
#     {'layer': '700mb', 'direction': 305, 'speed': 4},
#     {'layer': '650mb', 'direction': 310, 'speed': 4},
#     {'layer': '600mb', 'direction': 320, 'speed': 5},
#     {'layer': '550mb', 'direction': 320, 'speed': 5},
#     {'layer': '500mb', 'direction': 315, 'speed': 6},
#     {'layer': '450mb', 'direction': 305, 'speed': 6},
#     {'layer': '400mb', 'direction': 315, 'speed': 6},
#     {'layer': '350mb', 'direction': 325, 'speed': 6},
#     {'layer': '300mb', 'direction': 310, 'speed': 5},
#     {'layer': '250mb', 'direction': 300, 'speed': 6},
#     {'layer': '200mb', 'direction': 310, 'speed': 7}],
#    'temp2m': 14,
#    'lifted_index': 15,
#    'rh2m': 0,
#    'msl_pressure': 1026,
#    'wind10m': {'direction': '205', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 51,
#    'cloudcover': 9,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 4},
#     {'layer': '900mb', 'rh': 6},
#     {'layer': '850mb', 'rh': 9},
#     {'layer': '800mb', 'rh': 11},
#     {'layer': '750mb', 'rh': 3},
#     {'layer': '700mb', 'rh': 0},
#     {'layer': '650mb', 'rh': 1},
#     {'layer': '600mb', 'rh': -1},
#     {'layer': '550mb', 'rh': 0},
#     {'layer': '500mb', 'rh': -1},
#     {'layer': '450mb', 'rh': 1},
#     {'layer': '400mb', 'rh': 0},
#     {'layer': '350mb', 'rh': 0},
#     {'layer': '300mb', 'rh': 1},
#     {'layer': '250mb', 'rh': 6},
#     {'layer': '200mb', 'rh': 11}],
#    'wind_profile': [{'layer': '950mb', 'direction': 355, 'speed': 2},
#     {'layer': '900mb', 'direction': 0, 'speed': 3},
#     {'layer': '850mb', 'direction': 355, 'speed': 4},
#     {'layer': '800mb', 'direction': 345, 'speed': 5},
#     {'layer': '750mb', 'direction': 340, 'speed': 4},
#     {'layer': '700mb', 'direction': 320, 'speed': 4},
#     {'layer': '650mb', 'direction': 315, 'speed': 4},
#     {'layer': '600mb', 'direction': 315, 'speed': 5},
#     {'layer': '550mb', 'direction': 320, 'speed': 5},
#     {'layer': '500mb', 'direction': 320, 'speed': 6},
#     {'layer': '450mb', 'direction': 315, 'speed': 6},
#     {'layer': '400mb', 'direction': 315, 'speed': 6},
#     {'layer': '350mb', 'direction': 315, 'speed': 6},
#     {'layer': '300mb', 'direction': 310, 'speed': 6},
#     {'layer': '250mb', 'direction': 310, 'speed': 5},
#     {'layer': '200mb', 'direction': 315, 'speed': 7}],
#    'temp2m': 14,
#    'lifted_index': 15,
#    'rh2m': 3,
#    'msl_pressure': 1025,
#    'wind10m': {'direction': '205', 'speed': 3},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 54,
#    'cloudcover': 6,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 6},
#     {'layer': '900mb', 'rh': 8},
#     {'layer': '850mb', 'rh': 9},
#     {'layer': '800mb', 'rh': 9},
#     {'layer': '750mb', 'rh': -1},
#     {'layer': '700mb', 'rh': -2},
#     {'layer': '650mb', 'rh': -2},
#     {'layer': '600mb', 'rh': -2},
#     {'layer': '550mb', 'rh': -3},
#     {'layer': '500mb', 'rh': 0},
#     {'layer': '450mb', 'rh': 3},
#     {'layer': '400mb', 'rh': 1},
#     {'layer': '350mb', 'rh': 1},
#     {'layer': '300mb', 'rh': 1},
#     {'layer': '250mb', 'rh': 8},
#     {'layer': '200mb', 'rh': 11}],
#    'wind_profile': [{'layer': '950mb', 'direction': 5, 'speed': 3},
#     {'layer': '900mb', 'direction': 355, 'speed': 4},
#     {'layer': '850mb', 'direction': 330, 'speed': 4},
#     {'layer': '800mb', 'direction': 330, 'speed': 4},
#     {'layer': '750mb', 'direction': 345, 'speed': 3},
#     {'layer': '700mb', 'direction': 335, 'speed': 3},
#     {'layer': '650mb', 'direction': 320, 'speed': 3},
#     {'layer': '600mb', 'direction': 315, 'speed': 4},
#     {'layer': '550mb', 'direction': 325, 'speed': 4},
#     {'layer': '500mb', 'direction': 325, 'speed': 5},
#     {'layer': '450mb', 'direction': 315, 'speed': 6},
#     {'layer': '400mb', 'direction': 310, 'speed': 6},
#     {'layer': '350mb', 'direction': 310, 'speed': 6},
#     {'layer': '300mb', 'direction': 310, 'speed': 6},
#     {'layer': '250mb', 'direction': 300, 'speed': 6},
#     {'layer': '200mb', 'direction': 325, 'speed': 7}],
#    'temp2m': 14,
#    'lifted_index': 15,
#    'rh2m': 6,
#    'msl_pressure': 1026,
#    'wind10m': {'direction': '200', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 57,
#    'cloudcover': 1,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 3},
#     {'layer': '900mb', 'rh': 4},
#     {'layer': '850mb', 'rh': 6},
#     {'layer': '800mb', 'rh': 6},
#     {'layer': '750mb', 'rh': -1},
#     {'layer': '700mb', 'rh': -2},
#     {'layer': '650mb', 'rh': -2},
#     {'layer': '600mb', 'rh': -3},
#     {'layer': '550mb', 'rh': -2},
#     {'layer': '500mb', 'rh': 3},
#     {'layer': '450mb', 'rh': 4},
#     {'layer': '400mb', 'rh': 4},
#     {'layer': '350mb', 'rh': 0},
#     {'layer': '300mb', 'rh': 3},
#     {'layer': '250mb', 'rh': 5},
#     {'layer': '200mb', 'rh': 10}],
#    'wind_profile': [{'layer': '950mb', 'direction': 215, 'speed': 2},
#     {'layer': '900mb', 'direction': 245, 'speed': 3},
#     {'layer': '850mb', 'direction': 280, 'speed': 3},
#     {'layer': '800mb', 'direction': 320, 'speed': 3},
#     {'layer': '750mb', 'direction': 330, 'speed': 3},
#     {'layer': '700mb', 'direction': 320, 'speed': 3},
#     {'layer': '650mb', 'direction': 310, 'speed': 3},
#     {'layer': '600mb', 'direction': 315, 'speed': 3},
#     {'layer': '550mb', 'direction': 325, 'speed': 4},
#     {'layer': '500mb', 'direction': 330, 'speed': 5},
#     {'layer': '450mb', 'direction': 325, 'speed': 5},
#     {'layer': '400mb', 'direction': 315, 'speed': 6},
#     {'layer': '350mb', 'direction': 310, 'speed': 5},
#     {'layer': '300mb', 'direction': 310, 'speed': 6},
#     {'layer': '250mb', 'direction': 315, 'speed': 7},
#     {'layer': '200mb', 'direction': 330, 'speed': 8}],
#    'temp2m': 14,
#    'lifted_index': 15,
#    'rh2m': 4,
#    'msl_pressure': 1027,
#    'wind10m': {'direction': '255', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 60,
#    'cloudcover': 3,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 4},
#     {'layer': '900mb', 'rh': 5},
#     {'layer': '850mb', 'rh': 3},
#     {'layer': '800mb', 'rh': 0},
#     {'layer': '750mb', 'rh': -1},
#     {'layer': '700mb', 'rh': -2},
#     {'layer': '650mb', 'rh': -2},
#     {'layer': '600mb', 'rh': -2},
#     {'layer': '550mb', 'rh': 0},
#     {'layer': '500mb', 'rh': 4},
#     {'layer': '450mb', 'rh': 6},
#     {'layer': '400mb', 'rh': 4},
#     {'layer': '350mb', 'rh': 3},
#     {'layer': '300mb', 'rh': 7},
#     {'layer': '250mb', 'rh': 16},
#     {'layer': '200mb', 'rh': 15}],
#    'wind_profile': [{'layer': '950mb', 'direction': 245, 'speed': 3},
#     {'layer': '900mb', 'direction': 300, 'speed': 2},
#     {'layer': '850mb', 'direction': 325, 'speed': 3},
#     {'layer': '800mb', 'direction': 330, 'speed': 3},
#     {'layer': '750mb', 'direction': 330, 'speed': 3},
#     {'layer': '700mb', 'direction': 315, 'speed': 3},
#     {'layer': '650mb', 'direction': 295, 'speed': 3},
#     {'layer': '600mb', 'direction': 290, 'speed': 3},
#     {'layer': '550mb', 'direction': 315, 'speed': 3},
#     {'layer': '500mb', 'direction': 320, 'speed': 5},
#     {'layer': '450mb', 'direction': 315, 'speed': 5},
#     {'layer': '400mb', 'direction': 305, 'speed': 5},
#     {'layer': '350mb', 'direction': 305, 'speed': 6},
#     {'layer': '300mb', 'direction': 310, 'speed': 6},
#     {'layer': '250mb', 'direction': 320, 'speed': 7},
#     {'layer': '200mb', 'direction': 325, 'speed': 7}],
#    'temp2m': 13,
#    'lifted_index': 15,
#    'rh2m': 5,
#    'msl_pressure': 1027,
#    'wind10m': {'direction': '270', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 63,
#    'cloudcover': 9,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 5},
#     {'layer': '900mb', 'rh': 5},
#     {'layer': '850mb', 'rh': 5},
#     {'layer': '800mb', 'rh': 0},
#     {'layer': '750mb', 'rh': -2},
#     {'layer': '700mb', 'rh': -2},
#     {'layer': '650mb', 'rh': -2},
#     {'layer': '600mb', 'rh': -1},
#     {'layer': '550mb', 'rh': 3},
#     {'layer': '500mb', 'rh': 6},
#     {'layer': '450mb', 'rh': 11},
#     {'layer': '400mb', 'rh': 13},
#     {'layer': '350mb', 'rh': 14},
#     {'layer': '300mb', 'rh': 13},
#     {'layer': '250mb', 'rh': 12},
#     {'layer': '200mb', 'rh': 9}],
#    'wind_profile': [{'layer': '950mb', 'direction': 240, 'speed': 2},
#     {'layer': '900mb', 'direction': 240, 'speed': 2},
#     {'layer': '850mb', 'direction': 255, 'speed': 2},
#     {'layer': '800mb', 'direction': 305, 'speed': 2},
#     {'layer': '750mb', 'direction': 320, 'speed': 3},
#     {'layer': '700mb', 'direction': 315, 'speed': 3},
#     {'layer': '650mb', 'direction': 300, 'speed': 4},
#     {'layer': '600mb', 'direction': 290, 'speed': 4},
#     {'layer': '550mb', 'direction': 290, 'speed': 4},
#     {'layer': '500mb', 'direction': 300, 'speed': 4},
#     {'layer': '450mb', 'direction': 300, 'speed': 5},
#     {'layer': '400mb', 'direction': 305, 'speed': 6},
#     {'layer': '350mb', 'direction': 320, 'speed': 6},
#     {'layer': '300mb', 'direction': 320, 'speed': 7},
#     {'layer': '250mb', 'direction': 320, 'speed': 7},
#     {'layer': '200mb', 'direction': 340, 'speed': 7}],
#    'temp2m': 12,
#    'lifted_index': 15,
#    'rh2m': 6,
#    'msl_pressure': 1026,
#    'wind10m': {'direction': '265', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 66,
#    'cloudcover': 9,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 5},
#     {'layer': '900mb', 'rh': 6},
#     {'layer': '850mb', 'rh': 6},
#     {'layer': '800mb', 'rh': 3},
#     {'layer': '750mb', 'rh': -1},
#     {'layer': '700mb', 'rh': -2},
#     {'layer': '650mb', 'rh': -2},
#     {'layer': '600mb', 'rh': -1},
#     {'layer': '550mb', 'rh': 3},
#     {'layer': '500mb', 'rh': 9},
#     {'layer': '450mb', 'rh': 15},
#     {'layer': '400mb', 'rh': 12},
#     {'layer': '350mb', 'rh': 7},
#     {'layer': '300mb', 'rh': 8},
#     {'layer': '250mb', 'rh': 10},
#     {'layer': '200mb', 'rh': 8}],
#    'wind_profile': [{'layer': '950mb', 'direction': 230, 'speed': 2},
#     {'layer': '900mb', 'direction': 240, 'speed': 3},
#     {'layer': '850mb', 'direction': 260, 'speed': 3},
#     {'layer': '800mb', 'direction': 285, 'speed': 3},
#     {'layer': '750mb', 'direction': 300, 'speed': 3},
#     {'layer': '700mb', 'direction': 310, 'speed': 3},
#     {'layer': '650mb', 'direction': 315, 'speed': 3},
#     {'layer': '600mb', 'direction': 305, 'speed': 4},
#     {'layer': '550mb', 'direction': 295, 'speed': 5},
#     {'layer': '500mb', 'direction': 290, 'speed': 5},
#     {'layer': '450mb', 'direction': 305, 'speed': 5},
#     {'layer': '400mb', 'direction': 320, 'speed': 6},
#     {'layer': '350mb', 'direction': 335, 'speed': 6},
#     {'layer': '300mb', 'direction': 340, 'speed': 6},
#     {'layer': '250mb', 'direction': 350, 'speed': 7},
#     {'layer': '200mb', 'direction': 345, 'speed': 7}],
#    'temp2m': 12,
#    'lifted_index': 15,
#    'rh2m': 6,
#    'msl_pressure': 1026,
#    'wind10m': {'direction': '355', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 69,
#    'cloudcover': 4,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 5},
#     {'layer': '900mb', 'rh': 5},
#     {'layer': '850mb', 'rh': 5},
#     {'layer': '800mb', 'rh': 3},
#     {'layer': '750mb', 'rh': -1},
#     {'layer': '700mb', 'rh': -2},
#     {'layer': '650mb', 'rh': -2},
#     {'layer': '600mb', 'rh': -2},
#     {'layer': '550mb', 'rh': 5},
#     {'layer': '500mb', 'rh': 11},
#     {'layer': '450mb', 'rh': 6},
#     {'layer': '400mb', 'rh': 5},
#     {'layer': '350mb', 'rh': 4},
#     {'layer': '300mb', 'rh': 9},
#     {'layer': '250mb', 'rh': 4},
#     {'layer': '200mb', 'rh': 8}],
#    'wind_profile': [{'layer': '950mb', 'direction': 240, 'speed': 2},
#     {'layer': '900mb', 'direction': 250, 'speed': 3},
#     {'layer': '850mb', 'direction': 265, 'speed': 3},
#     {'layer': '800mb', 'direction': 280, 'speed': 3},
#     {'layer': '750mb', 'direction': 295, 'speed': 3},
#     {'layer': '700mb', 'direction': 305, 'speed': 3},
#     {'layer': '650mb', 'direction': 310, 'speed': 3},
#     {'layer': '600mb', 'direction': 300, 'speed': 4},
#     {'layer': '550mb', 'direction': 305, 'speed': 5},
#     {'layer': '500mb', 'direction': 310, 'speed': 5},
#     {'layer': '450mb', 'direction': 320, 'speed': 5},
#     {'layer': '400mb', 'direction': 340, 'speed': 5},
#     {'layer': '350mb', 'direction': 355, 'speed': 6},
#     {'layer': '300mb', 'direction': 350, 'speed': 6},
#     {'layer': '250mb', 'direction': 15, 'speed': 6},
#     {'layer': '200mb', 'direction': 345, 'speed': 7}],
#    'temp2m': 12,
#    'lifted_index': 15,
#    'rh2m': 5,
#    'msl_pressure': 1027,
#    'wind10m': {'direction': '290', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 72,
#    'cloudcover': 3,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 5},
#     {'layer': '900mb', 'rh': 5},
#     {'layer': '850mb', 'rh': 3},
#     {'layer': '800mb', 'rh': 1},
#     {'layer': '750mb', 'rh': -2},
#     {'layer': '700mb', 'rh': -2},
#     {'layer': '650mb', 'rh': -3},
#     {'layer': '600mb', 'rh': 2},
#     {'layer': '550mb', 'rh': 5},
#     {'layer': '500mb', 'rh': 5},
#     {'layer': '450mb', 'rh': 3},
#     {'layer': '400mb', 'rh': 5},
#     {'layer': '350mb', 'rh': -1},
#     {'layer': '300mb', 'rh': 1},
#     {'layer': '250mb', 'rh': 12},
#     {'layer': '200mb', 'rh': 9}],
#    'wind_profile': [{'layer': '950mb', 'direction': 260, 'speed': 2},
#     {'layer': '900mb', 'direction': 270, 'speed': 2},
#     {'layer': '850mb', 'direction': 280, 'speed': 3},
#     {'layer': '800mb', 'direction': 285, 'speed': 3},
#     {'layer': '750mb', 'direction': 285, 'speed': 3},
#     {'layer': '700mb', 'direction': 285, 'speed': 3},
#     {'layer': '650mb', 'direction': 290, 'speed': 3},
#     {'layer': '600mb', 'direction': 305, 'speed': 3},
#     {'layer': '550mb', 'direction': 300, 'speed': 4},
#     {'layer': '500mb', 'direction': 320, 'speed': 4},
#     {'layer': '450mb', 'direction': 335, 'speed': 5},
#     {'layer': '400mb', 'direction': 335, 'speed': 5},
#     {'layer': '350mb', 'direction': 345, 'speed': 5},
#     {'layer': '300mb', 'direction': 345, 'speed': 5},
#     {'layer': '250mb', 'direction': 350, 'speed': 6},
#     {'layer': '200mb', 'direction': 340, 'speed': 7}],
#    'temp2m': 13,
#    'lifted_index': 15,
#    'rh2m': 3,
#    'msl_pressure': 1025,
#    'wind10m': {'direction': '195', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 75,
#    'cloudcover': 2,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 4},
#     {'layer': '900mb', 'rh': 4},
#     {'layer': '850mb', 'rh': 3},
#     {'layer': '800mb', 'rh': -1},
#     {'layer': '750mb', 'rh': -2},
#     {'layer': '700mb', 'rh': -3},
#     {'layer': '650mb', 'rh': 1},
#     {'layer': '600mb', 'rh': 3},
#     {'layer': '550mb', 'rh': 5},
#     {'layer': '500mb', 'rh': 4},
#     {'layer': '450mb', 'rh': 1},
#     {'layer': '400mb', 'rh': 1},
#     {'layer': '350mb', 'rh': -2},
#     {'layer': '300mb', 'rh': 4},
#     {'layer': '250mb', 'rh': 13},
#     {'layer': '200mb', 'rh': 15}],
#    'wind_profile': [{'layer': '950mb', 'direction': 245, 'speed': 2},
#     {'layer': '900mb', 'direction': 295, 'speed': 2},
#     {'layer': '850mb', 'direction': 310, 'speed': 2},
#     {'layer': '800mb', 'direction': 275, 'speed': 3},
#     {'layer': '750mb', 'direction': 270, 'speed': 3},
#     {'layer': '700mb', 'direction': 280, 'speed': 3},
#     {'layer': '650mb', 'direction': 300, 'speed': 3},
#     {'layer': '600mb', 'direction': 305, 'speed': 3},
#     {'layer': '550mb', 'direction': 305, 'speed': 4},
#     {'layer': '500mb', 'direction': 305, 'speed': 4},
#     {'layer': '450mb', 'direction': 305, 'speed': 3},
#     {'layer': '400mb', 'direction': 310, 'speed': 4},
#     {'layer': '350mb', 'direction': 320, 'speed': 4},
#     {'layer': '300mb', 'direction': 330, 'speed': 5},
#     {'layer': '250mb', 'direction': 330, 'speed': 5},
#     {'layer': '200mb', 'direction': 325, 'speed': 6}],
#    'temp2m': 13,
#    'lifted_index': 15,
#    'rh2m': 5,
#    'msl_pressure': 1023,
#    'wind10m': {'direction': '195', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 78,
#    'cloudcover': 3,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 5},
#     {'layer': '900mb', 'rh': 5},
#     {'layer': '850mb', 'rh': 4},
#     {'layer': '800mb', 'rh': 0},
#     {'layer': '750mb', 'rh': -2},
#     {'layer': '700mb', 'rh': 0},
#     {'layer': '650mb', 'rh': 1},
#     {'layer': '600mb', 'rh': 4},
#     {'layer': '550mb', 'rh': 5},
#     {'layer': '500mb', 'rh': 2},
#     {'layer': '450mb', 'rh': 0},
#     {'layer': '400mb', 'rh': -1},
#     {'layer': '350mb', 'rh': -2},
#     {'layer': '300mb', 'rh': 5},
#     {'layer': '250mb', 'rh': 15},
#     {'layer': '200mb', 'rh': 14}],
#    'wind_profile': [{'layer': '950mb', 'direction': 210, 'speed': 2},
#     {'layer': '900mb', 'direction': 250, 'speed': 3},
#     {'layer': '850mb', 'direction': 280, 'speed': 3},
#     {'layer': '800mb', 'direction': 285, 'speed': 3},
#     {'layer': '750mb', 'direction': 270, 'speed': 3},
#     {'layer': '700mb', 'direction': 270, 'speed': 3},
#     {'layer': '650mb', 'direction': 280, 'speed': 3},
#     {'layer': '600mb', 'direction': 295, 'speed': 3},
#     {'layer': '550mb', 'direction': 300, 'speed': 4},
#     {'layer': '500mb', 'direction': 295, 'speed': 4},
#     {'layer': '450mb', 'direction': 280, 'speed': 4},
#     {'layer': '400mb', 'direction': 285, 'speed': 5},
#     {'layer': '350mb', 'direction': 280, 'speed': 3},
#     {'layer': '300mb', 'direction': 290, 'speed': 4},
#     {'layer': '250mb', 'direction': 305, 'speed': 6},
#     {'layer': '200mb', 'direction': 325, 'speed': 6}],
#    'temp2m': 14,
#    'lifted_index': 15,
#    'rh2m': 7,
#    'msl_pressure': 1023,
#    'wind10m': {'direction': '205', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 81,
#    'cloudcover': 9,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 5},
#     {'layer': '900mb', 'rh': 5},
#     {'layer': '850mb', 'rh': 5},
#     {'layer': '800mb', 'rh': 2},
#     {'layer': '750mb', 'rh': 0},
#     {'layer': '700mb', 'rh': 0},
#     {'layer': '650mb', 'rh': 0},
#     {'layer': '600mb', 'rh': 2},
#     {'layer': '550mb', 'rh': 5},
#     {'layer': '500mb', 'rh': 5},
#     {'layer': '450mb', 'rh': 4},
#     {'layer': '400mb', 'rh': -2},
#     {'layer': '350mb', 'rh': -1},
#     {'layer': '300mb', 'rh': 2},
#     {'layer': '250mb', 'rh': 10},
#     {'layer': '200mb', 'rh': 9}],
#    'wind_profile': [{'layer': '950mb', 'direction': 200, 'speed': 2},
#     {'layer': '900mb', 'direction': 225, 'speed': 2},
#     {'layer': '850mb', 'direction': 265, 'speed': 2},
#     {'layer': '800mb', 'direction': 275, 'speed': 3},
#     {'layer': '750mb', 'direction': 275, 'speed': 3},
#     {'layer': '700mb', 'direction': 275, 'speed': 3},
#     {'layer': '650mb', 'direction': 280, 'speed': 3},
#     {'layer': '600mb', 'direction': 285, 'speed': 3},
#     {'layer': '550mb', 'direction': 285, 'speed': 3},
#     {'layer': '500mb', 'direction': 290, 'speed': 4},
#     {'layer': '450mb', 'direction': 285, 'speed': 4},
#     {'layer': '400mb', 'direction': 265, 'speed': 5},
#     {'layer': '350mb', 'direction': 275, 'speed': 5},
#     {'layer': '300mb', 'direction': 290, 'speed': 5},
#     {'layer': '250mb', 'direction': 310, 'speed': 5},
#     {'layer': '200mb', 'direction': 330, 'speed': 7}],
#    'temp2m': 13,
#    'lifted_index': 15,
#    'rh2m': 7,
#    'msl_pressure': 1023,
#    'wind10m': {'direction': '325', 'speed': 2},
#    'prec_type': 'none',
#    'prec_amount': 0,
#    'snow_depth': 0},
#   {'timepoint': 84,
#    'cloudcover': 5,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 5},
#     {'layer': '900mb', 'rh': 5},
#     {'layer': '850mb', 'rh': 5},
#     {'layer': '800mb', 'rh': 4},
#     {'layer': '750mb', 'rh': -1},
#     {'layer': '700mb', 'rh': -1},
#     {'layer': '650mb', 'rh': -1},
#     {'layer': '600mb', 'rh': -1},
#     {'layer': '550mb', 'rh': 4},
#     {'layer': '500mb', 'rh': 6},
#     {'layer': '450mb', 'rh': 10},
#     {'layer': '400mb', 'rh': 6},
#     {'layer': '350mb', 'rh': 2},
#     {'layer': '300mb', 'rh': 5},
#     {'layer': '250mb', 'rh': 15},
#     {'layer': '200mb', 'rh': 12}],
#    'wind_profile': [{'layer': '950mb', 'direction': 260, 'speed': 2},
#     {'layer': '900mb', 'direction': 240, 'speed': 2},
#     {'layer': '850mb', 'direction': 260, 'speed': 3},
#     {'layer': '800mb', 'direction': 280, 'speed': 3},
#     {'layer': '750mb', 'direction': 285, 'speed': 3},
#     {'layer': '700mb', 'direction': 270, 'speed': 4},
#     {'layer': '650mb', 'direction': 260, 'speed': 4},
#     {'layer': '600mb', 'direction': 265, 'speed': 4},
#     {'layer': '550mb', 'direction': 265, 'speed': 4},
# ...
#     {'layer': '400mb', 'direction': 230, 'speed': 5},
#     {'layer': '350mb', 'direction': 235, 'speed': 5},
#     {'layer': '300mb', 'direction': 240, 'speed': 6},
#     {'layer': '250mb', 'direction': 200, 'speed': 6},
#     {'layer': '200mb', 'direction': 205, 'speed': 7}],
#    'temp2m': 26,
#    'lifted_index': -4,
#    'rh2m': 12,
#    'msl_pressure': 1010,
#    'wind10m': {'direction': '80', 'speed': 4},
#    'prec_type': 'rain',
#    'prec_amount': 3,
#    'snow_depth': 0},
#   {'timepoint': 168,
#    'cloudcover': 2,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 14},
#     {'layer': '900mb', 'rh': 13},
#     {'layer': '850mb', 'rh': 12},
#     {'layer': '800mb', 'rh': 9},
#     {'layer': '750mb', 'rh': 6},
#     {'layer': '700mb', 'rh': 1},
#     {'layer': '650mb', 'rh': 8},
#     {'layer': '600mb', 'rh': 9},
#     {'layer': '550mb', 'rh': 6},
#     {'layer': '500mb', 'rh': 10},
#     {'layer': '450mb', 'rh': 4},
#     {'layer': '400mb', 'rh': 3},
#     {'layer': '350mb', 'rh': 5},
#     {'layer': '300mb', 'rh': 11},
#     {'layer': '250mb', 'rh': 1},
#     {'layer': '200mb', 'rh': 7}],
#    'wind_profile': [{'layer': '950mb', 'direction': 85, 'speed': 5},
#     {'layer': '900mb', 'direction': 90, 'speed': 5},
#     {'layer': '850mb', 'direction': 100, 'speed': 5},
#     {'layer': '800mb', 'direction': 100, 'speed': 5},
#     {'layer': '750mb', 'direction': 100, 'speed': 4},
#     {'layer': '700mb', 'direction': 95, 'speed': 3},
#     {'layer': '650mb', 'direction': 170, 'speed': 2},
#     {'layer': '600mb', 'direction': 250, 'speed': 3},
#     {'layer': '550mb', 'direction': 245, 'speed': 3},
#     {'layer': '500mb', 'direction': 245, 'speed': 4},
#     {'layer': '450mb', 'direction': 250, 'speed': 5},
#     {'layer': '400mb', 'direction': 235, 'speed': 5},
#     {'layer': '350mb', 'direction': 240, 'speed': 6},
#     {'layer': '300mb', 'direction': 235, 'speed': 6},
#     {'layer': '250mb', 'direction': 205, 'speed': 6},
#     {'layer': '200mb', 'direction': 205, 'speed': 7}],
#    'temp2m': 25,
#    'lifted_index': -1,
#    'rh2m': 11,
#    'msl_pressure': 1008,
#    'wind10m': {'direction': '85', 'speed': 4},
#    'prec_type': 'rain',
#    'prec_amount': 3,
#    'snow_depth': 0},
#   {'timepoint': 171,
#    'cloudcover': 3,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 13},
#     {'layer': '900mb', 'rh': 12},
#     {'layer': '850mb', 'rh': 12},
#     {'layer': '800mb', 'rh': 11},
#     {'layer': '750mb', 'rh': 5},
#     {'layer': '700mb', 'rh': 0},
#     {'layer': '650mb', 'rh': 8},
#     {'layer': '600mb', 'rh': 7},
#     {'layer': '550mb', 'rh': 3},
#     {'layer': '500mb', 'rh': 8},
#     {'layer': '450mb', 'rh': 5},
#     {'layer': '400mb', 'rh': 6},
#     {'layer': '350mb', 'rh': 7},
#     {'layer': '300mb', 'rh': 11},
#     {'layer': '250mb', 'rh': 5},
#     {'layer': '200mb', 'rh': 1}],
#    'wind_profile': [{'layer': '950mb', 'direction': 85, 'speed': 5},
#     {'layer': '900mb', 'direction': 90, 'speed': 5},
#     {'layer': '850mb', 'direction': 95, 'speed': 5},
#     {'layer': '800mb', 'direction': 100, 'speed': 5},
#     {'layer': '750mb', 'direction': 100, 'speed': 4},
#     {'layer': '700mb', 'direction': 90, 'speed': 3},
#     {'layer': '650mb', 'direction': 175, 'speed': 2},
#     {'layer': '600mb', 'direction': 245, 'speed': 3},
#     {'layer': '550mb', 'direction': 250, 'speed': 3},
#     {'layer': '500mb', 'direction': 245, 'speed': 4},
#     {'layer': '450mb', 'direction': 240, 'speed': 5},
#     {'layer': '400mb', 'direction': 235, 'speed': 5},
#     {'layer': '350mb', 'direction': 240, 'speed': 6},
#     {'layer': '300mb', 'direction': 240, 'speed': 5},
#     {'layer': '250mb', 'direction': 200, 'speed': 7},
#     {'layer': '200mb', 'direction': 200, 'speed': 7}],
#    'temp2m': 25,
#    'lifted_index': -4,
#    'rh2m': 11,
#    'msl_pressure': 1009,
#    'wind10m': {'direction': '85', 'speed': 4},
#    'prec_type': 'rain',
#    'prec_amount': 3,
#    'snow_depth': 0},
#   {'timepoint': 174,
#    'cloudcover': 2,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 14},
#     {'layer': '900mb', 'rh': 13},
#     {'layer': '850mb', 'rh': 10},
#     {'layer': '800mb', 'rh': 8},
#     {'layer': '750mb', 'rh': 3},
#     {'layer': '700mb', 'rh': 0},
#     {'layer': '650mb', 'rh': 8},
#     {'layer': '600mb', 'rh': 6},
#     {'layer': '550mb', 'rh': 3},
#     {'layer': '500mb', 'rh': 5},
#     {'layer': '450mb', 'rh': 5},
#     {'layer': '400mb', 'rh': 8},
#     {'layer': '350mb', 'rh': 9},
#     {'layer': '300mb', 'rh': 11},
#     {'layer': '250mb', 'rh': 1},
#     {'layer': '200mb', 'rh': 9}],
#    'wind_profile': [{'layer': '950mb', 'direction': 80, 'speed': 4},
#     {'layer': '900mb', 'direction': 80, 'speed': 5},
#     {'layer': '850mb', 'direction': 90, 'speed': 5},
#     {'layer': '800mb', 'direction': 100, 'speed': 5},
#     {'layer': '750mb', 'direction': 95, 'speed': 4},
#     {'layer': '700mb', 'direction': 85, 'speed': 3},
#     {'layer': '650mb', 'direction': 150, 'speed': 2},
#     {'layer': '600mb', 'direction': 240, 'speed': 3},
#     {'layer': '550mb', 'direction': 250, 'speed': 3},
#     {'layer': '500mb', 'direction': 240, 'speed': 4},
#     {'layer': '450mb', 'direction': 240, 'speed': 5},
#     {'layer': '400mb', 'direction': 235, 'speed': 5},
#     {'layer': '350mb', 'direction': 240, 'speed': 6},
#     {'layer': '300mb', 'direction': 235, 'speed': 5},
#     {'layer': '250mb', 'direction': 200, 'speed': 7},
#     {'layer': '200mb', 'direction': 200, 'speed': 7}],
#    'temp2m': 26,
#    'lifted_index': -4,
#    'rh2m': 11,
#    'msl_pressure': 1011,
#    'wind10m': {'direction': '80', 'speed': 4},
#    'prec_type': 'rain',
#    'prec_amount': 3,
#    'snow_depth': 0},
#   {'timepoint': 177,
#    'cloudcover': 4,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 14},
#     {'layer': '900mb', 'rh': 13},
#     {'layer': '850mb', 'rh': 12},
#     {'layer': '800mb', 'rh': 10},
#     {'layer': '750mb', 'rh': 4},
#     {'layer': '700mb', 'rh': 0},
#     {'layer': '650mb', 'rh': 7},
#     {'layer': '600mb', 'rh': 4},
#     {'layer': '550mb', 'rh': 3},
#     {'layer': '500mb', 'rh': 3},
#     {'layer': '450mb', 'rh': 5},
#     {'layer': '400mb', 'rh': 8},
#     {'layer': '350mb', 'rh': 10},
#     {'layer': '300mb', 'rh': 15},
#     {'layer': '250mb', 'rh': 0},
#     {'layer': '200mb', 'rh': 14}],
#    'wind_profile': [{'layer': '950mb', 'direction': 75, 'speed': 4},
#     {'layer': '900mb', 'direction': 80, 'speed': 5},
#     {'layer': '850mb', 'direction': 85, 'speed': 5},
#     {'layer': '800mb', 'direction': 90, 'speed': 5},
#     {'layer': '750mb', 'direction': 90, 'speed': 4},
#     {'layer': '700mb', 'direction': 70, 'speed': 3},
#     {'layer': '650mb', 'direction': 0, 'speed': 2},
#     {'layer': '600mb', 'direction': 260, 'speed': 3},
#     {'layer': '550mb', 'direction': 260, 'speed': 3},
#     {'layer': '500mb', 'direction': 245, 'speed': 4},
#     {'layer': '450mb', 'direction': 230, 'speed': 5},
#     {'layer': '400mb', 'direction': 225, 'speed': 5},
#     {'layer': '350mb', 'direction': 235, 'speed': 6},
#     {'layer': '300mb', 'direction': 245, 'speed': 6},
#     {'layer': '250mb', 'direction': 195, 'speed': 7},
#     {'layer': '200mb', 'direction': 205, 'speed': 7}],
#    'temp2m': 26,
#    'lifted_index': -1,
#    'rh2m': 11,
#    'msl_pressure': 1010,
#    'wind10m': {'direction': '75', 'speed': 4},
#    'prec_type': 'rain',
#    'prec_amount': 3,
#    'snow_depth': 0},
#   {'timepoint': 180,
#    'cloudcover': 4,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 14},
#     {'layer': '900mb', 'rh': 13},
#     {'layer': '850mb', 'rh': 12},
#     {'layer': '800mb', 'rh': 11},
#     {'layer': '750mb', 'rh': 2},
#     {'layer': '700mb', 'rh': 0},
#     {'layer': '650mb', 'rh': 6},
#     {'layer': '600mb', 'rh': 4},
#     {'layer': '550mb', 'rh': 3},
#     {'layer': '500mb', 'rh': 4},
#     {'layer': '450mb', 'rh': 5},
#     {'layer': '400mb', 'rh': 7},
#     {'layer': '350mb', 'rh': 11},
#     {'layer': '300mb', 'rh': 12},
#     {'layer': '250mb', 'rh': 1},
#     {'layer': '200mb', 'rh': 10}],
#    'wind_profile': [{'layer': '950mb', 'direction': 75, 'speed': 4},
#     {'layer': '900mb', 'direction': 80, 'speed': 5},
#     {'layer': '850mb', 'direction': 85, 'speed': 5},
#     {'layer': '800mb', 'direction': 90, 'speed': 5},
#     {'layer': '750mb', 'direction': 85, 'speed': 4},
#     {'layer': '700mb', 'direction': 80, 'speed': 3},
#     {'layer': '650mb', 'direction': 145, 'speed': 2},
#     {'layer': '600mb', 'direction': 245, 'speed': 3},
#     {'layer': '550mb', 'direction': 265, 'speed': 3},
#     {'layer': '500mb', 'direction': 255, 'speed': 4},
#     {'layer': '450mb', 'direction': 245, 'speed': 5},
#     {'layer': '400mb', 'direction': 230, 'speed': 5},
#     {'layer': '350mb', 'direction': 235, 'speed': 6},
#     {'layer': '300mb', 'direction': 240, 'speed': 6},
#     {'layer': '250mb', 'direction': 200, 'speed': 7},
#     {'layer': '200mb', 'direction': 200, 'speed': 7}],
#    'temp2m': 26,
#    'lifted_index': -1,
#    'rh2m': 11,
#    'msl_pressure': 1007,
#    'wind10m': {'direction': '75', 'speed': 3},
#    'prec_type': 'rain',
#    'prec_amount': 3,
#    'snow_depth': 0},
#   {'timepoint': 183,
#    'cloudcover': 2,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 14},
#     {'layer': '900mb', 'rh': 13},
#     {'layer': '850mb', 'rh': 10},
#     {'layer': '800mb', 'rh': 9},
#     {'layer': '750mb', 'rh': 3},
#     {'layer': '700mb', 'rh': 0},
#     {'layer': '650mb', 'rh': 6},
#     {'layer': '600mb', 'rh': 3},
#     {'layer': '550mb', 'rh': 3},
#     {'layer': '500mb', 'rh': 5},
#     {'layer': '450mb', 'rh': 5},
#     {'layer': '400mb', 'rh': 6},
#     {'layer': '350mb', 'rh': 5},
#     {'layer': '300mb', 'rh': 11},
#     {'layer': '250mb', 'rh': 2},
#     {'layer': '200mb', 'rh': 10}],
#    'wind_profile': [{'layer': '950mb', 'direction': 70, 'speed': 4},
#     {'layer': '900mb', 'direction': 80, 'speed': 5},
#     {'layer': '850mb', 'direction': 85, 'speed': 5},
#     {'layer': '800mb', 'direction': 85, 'speed': 5},
#     {'layer': '750mb', 'direction': 85, 'speed': 4},
#     {'layer': '700mb', 'direction': 85, 'speed': 3},
#     {'layer': '650mb', 'direction': 145, 'speed': 2},
#     {'layer': '600mb', 'direction': 230, 'speed': 3},
#     {'layer': '550mb', 'direction': 245, 'speed': 3},
#     {'layer': '500mb', 'direction': 250, 'speed': 4},
#     {'layer': '450mb', 'direction': 245, 'speed': 5},
#     {'layer': '400mb', 'direction': 240, 'speed': 5},
#     {'layer': '350mb', 'direction': 225, 'speed': 6},
#     {'layer': '300mb', 'direction': 245, 'speed': 6},
#     {'layer': '250mb', 'direction': 190, 'speed': 7},
#     {'layer': '200mb', 'direction': 200, 'speed': 7}],
#    'temp2m': 26,
#    'lifted_index': -4,
#    'rh2m': 11,
#    'msl_pressure': 1008,
#    'wind10m': {'direction': '75', 'speed': 3},
#    'prec_type': 'rain',
#    'prec_amount': 3,
#    'snow_depth': 0},
#   {'timepoint': 186,
#    'cloudcover': 2,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 14},
#     {'layer': '900mb', 'rh': 13},
#     {'layer': '850mb', 'rh': 10},
#     {'layer': '800mb', 'rh': 8},
#     {'layer': '750mb', 'rh': 4},
#     {'layer': '700mb', 'rh': 0},
#     {'layer': '650mb', 'rh': 5},
#     {'layer': '600mb', 'rh': 3},
#     {'layer': '550mb', 'rh': 4},
#     {'layer': '500mb', 'rh': 5},
#     {'layer': '450mb', 'rh': 4},
#     {'layer': '400mb', 'rh': 4},
#     {'layer': '350mb', 'rh': 6},
#     {'layer': '300mb', 'rh': 2},
#     {'layer': '250mb', 'rh': 6},
#     {'layer': '200mb', 'rh': 11}],
#    'wind_profile': [{'layer': '950mb', 'direction': 75, 'speed': 4},
#     {'layer': '900mb', 'direction': 85, 'speed': 5},
#     {'layer': '850mb', 'direction': 90, 'speed': 5},
#     {'layer': '800mb', 'direction': 90, 'speed': 5},
#     {'layer': '750mb', 'direction': 90, 'speed': 5},
#     {'layer': '700mb', 'direction': 85, 'speed': 4},
#     {'layer': '650mb', 'direction': 105, 'speed': 2},
#     {'layer': '600mb', 'direction': 240, 'speed': 3},
#     {'layer': '550mb', 'direction': 255, 'speed': 3},
#     {'layer': '500mb', 'direction': 255, 'speed': 4},
#     {'layer': '450mb', 'direction': 250, 'speed': 5},
#     {'layer': '400mb', 'direction': 235, 'speed': 5},
#     {'layer': '350mb', 'direction': 230, 'speed': 6},
#     {'layer': '300mb', 'direction': 230, 'speed': 6},
#     {'layer': '250mb', 'direction': 200, 'speed': 7},
#     {'layer': '200mb', 'direction': 190, 'speed': 7}],
#    'temp2m': 26,
#    'lifted_index': -1,
#    'rh2m': 11,
#    'msl_pressure': 1010,
#    'wind10m': {'direction': '75', 'speed': 4},
#    'prec_type': 'rain',
#    'prec_amount': 3,
#    'snow_depth': 0},
#   {'timepoint': 189,
#    'cloudcover': 1,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 14},
#     {'layer': '900mb', 'rh': 12},
#     {'layer': '850mb', 'rh': 13},
#     {'layer': '800mb', 'rh': 4},
#     {'layer': '750mb', 'rh': 2},
#     {'layer': '700mb', 'rh': 1},
#     {'layer': '650mb', 'rh': 3},
#     {'layer': '600mb', 'rh': 5},
#     {'layer': '550mb', 'rh': 6},
#     {'layer': '500mb', 'rh': 7},
#     {'layer': '450mb', 'rh': 5},
#     {'layer': '400mb', 'rh': 4},
#     {'layer': '350mb', 'rh': 4},
#     {'layer': '300mb', 'rh': 1},
#     {'layer': '250mb', 'rh': 6},
#     {'layer': '200mb', 'rh': 3}],
#    'wind_profile': [{'layer': '950mb', 'direction': 75, 'speed': 4},
#     {'layer': '900mb', 'direction': 90, 'speed': 5},
#     {'layer': '850mb', 'direction': 90, 'speed': 5},
#     {'layer': '800mb', 'direction': 95, 'speed': 5},
#     {'layer': '750mb', 'direction': 95, 'speed': 5},
#     {'layer': '700mb', 'direction': 85, 'speed': 4},
#     {'layer': '650mb', 'direction': 90, 'speed': 3},
#     {'layer': '600mb', 'direction': 235, 'speed': 2},
#     {'layer': '550mb', 'direction': 265, 'speed': 3},
#     {'layer': '500mb', 'direction': 260, 'speed': 4},
#     {'layer': '450mb', 'direction': 250, 'speed': 4},
#     {'layer': '400mb', 'direction': 235, 'speed': 5},
#     {'layer': '350mb', 'direction': 225, 'speed': 5},
#     {'layer': '300mb', 'direction': 240, 'speed': 5},
#     {'layer': '250mb', 'direction': 190, 'speed': 7},
#     {'layer': '200mb', 'direction': 200, 'speed': 7}],
#    'temp2m': 26,
#    'lifted_index': -1,
#    'rh2m': 11,
#    'msl_pressure': 1010,
#    'wind10m': {'direction': '80', 'speed': 3},
#    'prec_type': 'rain',
#    'prec_amount': 3,
#    'snow_depth': 0},
#   {'timepoint': 192,
#    'cloudcover': 1,
#    'highcloud': -9999,
#    'midcloud': -9999,
#    'lowcloud': -9999,
#    'rh_profile': [{'layer': '950mb', 'rh': 13},
#     {'layer': '900mb', 'rh': 13},
#     {'layer': '850mb', 'rh': 5},
#     {'layer': '800mb', 'rh': 1},
#     {'layer': '750mb', 'rh': 1},
#     {'layer': '700mb', 'rh': 1},
#     {'layer': '650mb', 'rh': 4},
#     {'layer': '600mb', 'rh': 6},
#     {'layer': '550mb', 'rh': 7},
#     {'layer': '500mb', 'rh': 7},
#     {'layer': '450mb', 'rh': 5},
#     {'layer': '400mb', 'rh': 4},
#     {'layer': '350mb', 'rh': 7},
#     {'layer': '300mb', 'rh': 3},
#     {'layer': '250mb', 'rh': 13},
#     {'layer': '200mb', 'rh': 3}],
#    'wind_profile': [{'layer': '950mb', 'direction': 80, 'speed': 4},
#     {'layer': '900mb', 'direction': 85, 'speed': 5},
#     {'layer': '850mb', 'direction': 90, 'speed': 5},
#     {'layer': '800mb', 'direction': 90, 'speed': 5},
#     {'layer': '750mb', 'direction': 90, 'speed': 5},
#     {'layer': '700mb', 'direction': 85, 'speed': 4},
#     {'layer': '650mb', 'direction': 90, 'speed': 2},
#     {'layer': '600mb', 'direction': 230, 'speed': 2},
#     {'layer': '550mb', 'direction': 265, 'speed': 3},
#     {'layer': '500mb', 'direction': 260, 'speed': 4},
#     {'layer': '450mb', 'direction': 250, 'speed': 5},
#     {'layer': '400mb', 'direction': 245, 'speed': 5},
#     {'layer': '350mb', 'direction': 225, 'speed': 5},
#     {'layer': '300mb', 'direction': 235, 'speed': 5},
#     {'layer': '250mb', 'direction': 205, 'speed': 6},
#     {'layer': '200mb', 'direction': 215, 'speed': 6}],
#    'temp2m': 25,
#    'lifted_index': -1,
#    'rh2m': 11,
#    'msl_pressure': 1008,
#    'wind10m': {'direction': '70', 'speed': 4},
#    'prec_type': 'rain',
#    'prec_amount': 3,
#    'snow_depth': 0}]}

# %%
df_final.head(2)
# Out:
#    timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0          3           1      -9999     -9999     -9999
# 1          6           1      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 1  [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 100, 'speed':...      25             2
# 1  [{'layer': '950mb', 'direction': 100, 'speed':...      26             2
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth wind10m.direction  \
# 0    11          1011      none            0           0               115
# 1    11          1013      none            1           0               100
#
#    wind10m.speed              pais
# 0              3  Papua New Guinea
# 1              3  Papua New Guinea

# %%
df_final.to_csv('files/1.paises_meteo_info.csv')
